# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
ds
# Out:
#                    A         B         C         D
# 2000-01-01  0.116551  0.843132  0.010260  0.648541
# 2000-01-02  0.141842  0.728954  0.526009  0.250024
# 2000-01-03  0.062776  0.768898  0.939951  0.257331
# 2000-01-04  0.968985  0.767024  0.040963  0.821987
# 2000-01-05  0.678493  0.830911  0.578576  0.542053
# 2000-01-06  0.481395  0.659701  0.558983  0.566053
# 2000-01-07  0.085936  0.464099  0.031802  0.766381
# 2000-01-08  0.559066  0.539918  0.363948  0.980980
# 2000-01-09  0.925280  0.728944  0.901804  0.221731
# 2000-01-10  0.342172  0.601934  0.728405  0.761723

# %%
plt.plot(ds)
plt.show()

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds
# Out:
#           A         B         C         D
# 0  0.806448  0.459495  0.898675  0.198786
# 1  0.249893  0.506014  0.793652  0.434942
# 2  0.659174  0.898433  0.981334  0.994578
# 3  0.745515  0.998729  0.285501  0.781047
# 4  0.126960  0.921918  0.125210  0.067608
# 5  0.709350  0.423931  0.005526  0.544063
# 6  0.244760  0.297778  0.926264  0.405451
# 7  0.363275  0.632976  0.918294  0.626334
# 8  0.560972  0.643146  0.287486  0.806113
# 9  0.456182  0.712449  0.876007  0.703017

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
ds
# Out:
#                    A         B         C         D
# 2000-01-01  0.370639  0.150984  0.010824  0.560276
# 2000-01-02  0.235168  0.721693  0.665679  0.792821
# 2000-01-03  0.221487  0.219441  0.556083  0.029464
# 2000-01-04  0.588525  0.550103  0.313288  0.525431
# 2000-01-05  0.150764  0.714001  0.763818  0.343711
# 2000-01-06  0.621900  0.076526  0.566754  0.235957
# 2000-01-07  0.879164  0.823847  0.907366  0.352600
# 2000-01-08  0.223502  0.241680  0.509596  0.740852
# 2000-01-09  0.541196  0.228931  0.376359  0.552831
# 2000-01-10  0.345403  0.195582  0.695405  0.540334

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds.plot.barh()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds.plot.area()
# Out:
# <AxesSubplot:>

# %%
ds.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
ds.plot.scatter(x='C',y='D')
# Out:
# <AxesSubplot:xlabel='C', ylabel='D'>

# %%
ds1=pd.DataFrame({'Name':["Lokesh","Palla","Manoj","Meda"],'Age':[20,19,19,20],'Department':["cse","cse","cse","cse"]})

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse

# %%
ds1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds1[ds1['Age']>=20]
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 3    Meda   20        cse

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse

# %%
ds1['Age']>=20
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: Age, dtype: bool

# %%
ds1[(ds1['Age']>=20) &( ds1['Age']<=25)]
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 3    Meda   20        cse

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse

# %%
ds1.loc[4]=['hani',18,'EEE']

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse
# 5    hani   18        EEE
# 4    hani   18        EEE

# %%
ds1.head()
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse
# 5    hani   18        EEE

# %%
ds1.tail()
# Out:
#     Name  Age Department
# 1  Palla   19        cse
# 2  Manoj   19        cse
# 3   Meda   20        cse
# 5   hani   18        EEE
# 4   hani   18        EEE

# %%
ds1.drop(5)
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse
# 4    hani   18        EEE

# %%
ds1.drop(3,inplace=True)

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4    hani   18        EEE

# %%
ds1.iloc[-1]='aee'

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds1.ffill()
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds1.bfill()
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds2=ds1

# %%
ds2
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds1.fillna(method='ffill')
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds1.fillna(method='ffill',axis=1)
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 5    hani   18        EEE
# 4     aee  aee        aee

# %%
ds1=pd.DataFrame({'Name':["Lokesh","Palla","Manoj","Meda"],'Age':[20,19,19,20],'Department':["cse","cse","cse","cse"]})

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds1=pd.DataFrame({'Name':["Lokesh","Palla","Manoj","Meda"],'Age':[20,19,19,20],'Department':["cse","cse","cse","cse"]})

# %%
ds1
# Out:
#      Name  Age Department
# 0  Lokesh   20        cse
# 1   Palla   19        cse
# 2   Manoj   19        cse
# 3    Meda   20        cse

# %%
ds1.isnull()
# Out:
#     Name    Age  Department
# 0  False  False       False
# 1  False  False       False
# 2  False  False       False
# 3  False  False       False

# %%
import seaborn as sns

# %%
sns.barplot(x='Name',y='Age',data=ds1)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
ds1.plot.area()
# Out:
# <AxesSubplot:>
